# %%
# !pip -q install amplpy
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 25.7 MB/s eta 0:00:00

# %%
# 1. Instalación e inicialización de AMPL con tu licencia Community Edition
from amplpy import ampl_notebook

# Inicializa AMPL en Colab con tu UUID (Community Edition) Inicializar AMPL
ampl = ampl_notebook(
    modules=["highs", "cbc", "gurobi", "cplex"],  # solvers disponibles
    license_uuid="936b618d-a013-406f-9809-49679f557c26"
)
# Out:
# Licensed to AMPL Academic Community Edition License for <m.godoyseplveda@uandresbello.edu>.

# %%
# %%writefile assignment.mod
# set I;            # personas
# set J;            # tareas
# param c{I,J};     # costos
#
# var x{I,J} binary;
#
# minimize Z: sum{i in I, j in J} c[i,j]*x[i,j];
#
# s.t. OneTaskPerPerson {i in I}: sum{j in J} x[i,j] = 1;
# s.t. OnePersonPerTask {j in J}: sum{i in I} x[i,j] = 1;
# Out:
# Writing assignment.mod

# %%
# %%writefile 8_3_8.dat
# set I := A B C ;
# set J := 1 2 3 ;
#
# param c :
#         1   2   3 :=
#   A     5   7   4
#   B     3   5   5
#   C     2   3   4 ;
# Out:
# Writing 8_3_8.dat

# %%
ampl.read('assignment.mod')
ampl.readData('8_3_8.dat')
ampl.option['solver'] = 'highs'
ampl.solve()
ampl.display('x','Z')
# Out:
# HiGHS 1.11.0: optimal solution; objective 10
# 5 simplex iterations
# 1 branching nodes
# x :=
# A 1   0
# A 2   0
# A 3   1
# B 1   1
# B 2   0
# B 3   0
# C 1   0
# C 2   1
# C 3   0
# ;
#
# Z = 10
